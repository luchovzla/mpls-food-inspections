# %%
# Import the functions we need from flask
from flask import Flask
from flask import render_template 
from flask import jsonify
from config import (user, password, host, port, database)

# Import the functions we need from SQL Alchemy
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
connection_string = f'postgresql://{user}:{password}@{host}:{port}/{database}'

# Connect to the database
engine = create_engine(connection_string)
base = automap_base()
base.prepare(engine, reflect=True)

# Choose the table we wish to use
table = base.classes.food_inspections

# # Instantiate the Flask application. (Chocolate cake recipe.)
# # This statement is required for Flask to do its job. 
# app = Flask(__name__)
# app.config['SEND_FILE_MAX_AGE_DEFAULT'] = 0 # Effectively disables page caching

# %%
# Here's where we define the various application routes ...
# @app.route("/")
# def IndexRoute():
#     ''' This function runs when the browser loads the index route. 
#         Note that the html file must be located in a folder called templates. '''

#     webpage = render_template("index.html")
#     return webpage

# @app.route("/choropleth")
# QueryFoodInspections():

#     ''' Query the database for food inspections and return the results as a JSON. '''

#     Open a session, run the query, and then close the session again
session = Session(engine)
results = session.query(table.business_name, table.address, table.inspection_type, table.inspection_score, table.neighborhood, table.latitude, table.longitude).all()
session.close()  

#         Create a list of dictionaries, with each dictionary containing one row from the query. 
all_restaurants = []
for business_name, address, inspection_type, inspection_score, neighborhood, latitude, longitude in results:
    dict = {}
    dict["business_name"] = business_name
    dict["address"] = address
    dict["inspection_type"] = inspection_type
    dict["inspection_score"] = inspection_score
    dict["neighborhood"] = neighborhood
    dict["latitude"] = latitude
    dict["longitude"] = longitude
    all_restaurants.append(dict)

# Return the jsonified result. 
# return jsonify(all_restaurants)

# This statement is required for Flask to do its job. 
# Think of it as chocolate cake recipe. 
# if __name__ == '__main__':
#     app.run(debug=True)

# %%
all_restaurants
# Out:
# [{'business_name': 'SOTAROL UPTOWN',
#   'address': '2935 GIRARD AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.94885'),
#   'longitude': Decimal('-93.29663000000001')},
#  {'business_name': 'SOTAROL UPTOWN',
#   'address': '2935 GIRARD AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.94885'),
#   'longitude': Decimal('-93.29663000000001')},
#  {'business_name': 'CRISP & GREEN',
#   'address': '428 WASHINGTON AVE N',
#   'inspection_type': 'Routine',
#   'inspection_score': 84,
#   'neighborhood': 'North Loop',
#   'latitude': Decimal('44.98619'),
#   'longitude': Decimal('-93.27411')},
#  {'business_name': 'LUCY BAR & RESTAURANT LIMITED LIABILITY COMPANY',
#   'address': '3915 HIAWATHA AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 82,
#   'neighborhood': 'Howe',
#   'latitude': Decimal('44.93168'),
#   'longitude': Decimal('-93.22639000000001')},
#  {'business_name': 'LUCY BAR & RESTAURANT LIMITED LIABILITY COMPANY',
#   'address': '3915 HIAWATHA AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 80,
#   'neighborhood': 'Howe',
#   'latitude': Decimal('44.93168'),
#   'longitude': Decimal('-93.22639000000001')},
#  {'business_name': 'LUCY BAR & RESTAURANT LIMITED LIABILITY COMPANY',
#   'address': '3915 HIAWATHA AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Howe',
#   'latitude': Decimal('44.93168'),
#   'longitude': Decimal('-93.22639000000001')},
#  {'business_name': 'LUCY BAR & RESTAURANT LIMITED LIABILITY COMPANY',
#   'address': '3915 HIAWATHA AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Howe',
#   'latitude': Decimal('44.93168'),
#   'longitude': Decimal('-93.22639000000001')},
#  {'business_name': 'DOUBLE DANGER, LLC',
#   'address': '113 26TH ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.95511'),
#   'longitude': Decimal('-93.27569')},
#  {'business_name': 'DOUBLE DANGER, LLC',
#   'address': '113 26TH ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.95511'),
#   'longitude': Decimal('-93.27569')},
#  {'business_name': 'DOUBLE DANGER, LLC',
#   'address': '113 26TH ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.95511'),
#   'longitude': Decimal('-93.27569')},
#  {'business_name': 'DOUBLE DANGER, LLC',
#   'address': '113 26TH ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 88,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.95511'),
#   'longitude': Decimal('-93.27569')},
#  {'business_name': 'DOUBLE DANGER, LLC',
#   'address': '113 26TH ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.95511'),
#   'longitude': Decimal('-93.27569')},
#  {'business_name': 'AFRO DELI AND COFFEE LLC',
#   'address': '720 WASHINGTON AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 80,
#   'neighborhood': 'University of Minnesota',
#   'latitude': Decimal('44.97333'),
#   'longitude': Decimal('-93.22759')},
#  {'business_name': 'AFRO DELI AND COFFEE LLC',
#   'address': '720 WASHINGTON AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'University of Minnesota',
#   'latitude': Decimal('44.97333'),
#   'longitude': Decimal('-93.22759')},
#  {'business_name': 'AFRO DELI AND COFFEE LLC',
#   'address': '720 WASHINGTON AVE SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 90,
#   'neighborhood': 'University of Minnesota',
#   'latitude': Decimal('44.97333'),
#   'longitude': Decimal('-93.22759')},
#  {'business_name': 'KUNG FU TEA',
#   'address': '507 14TH AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98232'),
#   'longitude': Decimal('-93.2356')},
#  {'business_name': 'KUNG FU TEA',
#   'address': '507 14TH AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98232'),
#   'longitude': Decimal('-93.2356')},
#  {'business_name': 'MARKET PLACE',
#   'address': '1300 NICOLLET MALL',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Loring Park',
#   'latitude': Decimal('44.970859999999995'),
#   'longitude': Decimal('-93.27826')},
#  {'business_name': 'MARKET PLACE',
#   'address': '1300 NICOLLET MALL',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Loring Park',
#   'latitude': Decimal('44.970859999999995'),
#   'longitude': Decimal('-93.27826')},
#  {'business_name': 'AMORE UPTOWN',
#   'address': '1601 LAKE ST W',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'ECCO',
#   'latitude': Decimal('44.94807'),
#   'longitude': Decimal('-93.30246')},
#  {'business_name': 'AMORE UPTOWN',
#   'address': '1601 LAKE ST W',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'ECCO',
#   'latitude': Decimal('44.94807'),
#   'longitude': Decimal('-93.30246')},
#  {'business_name': 'AMORE UPTOWN',
#   'address': '1601 LAKE ST W',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'ECCO',
#   'latitude': Decimal('44.94807'),
#   'longitude': Decimal('-93.30246')},
#  {'business_name': 'AMORE UPTOWN',
#   'address': '1601 LAKE ST W',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'ECCO',
#   'latitude': Decimal('44.94807'),
#   'longitude': Decimal('-93.30246')},
#  {'business_name': 'ANDREA PIZZA',
#   'address': '811 LASALLE AVE #SUITE 202',
#   'inspection_type': 'Routine',
#   'inspection_score': 88,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97592'),
#   'longitude': Decimal('-93.27444')},
#  {'business_name': 'ANDREA PIZZA',
#   'address': '811 LASALLE AVE #SUITE 202',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97592'),
#   'longitude': Decimal('-93.27444')},
#  {'business_name': 'ANDREA PIZZA',
#   'address': '225 6TH ST S #A203',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.976000000000006'),
#   'longitude': Decimal('-93.26826')},
#  {'business_name': 'ANDREA PIZZA',
#   'address': '225 6TH ST S #A203',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.976000000000006'),
#   'longitude': Decimal('-93.26826')},
#  {'business_name': "ANDREA'S PIZZA",
#   'address': '330 2ND AVE S #214',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97927'),
#   'longitude': Decimal('-93.26702')},
#  {'business_name': "ANDREA'S PIZZA",
#   'address': '330 2ND AVE S #214',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97927'),
#   'longitude': Decimal('-93.26702')},
#  {'business_name': "ANDREA'S PIZZA",
#   'address': '330 2ND AVE S #214',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97927'),
#   'longitude': Decimal('-93.26702')},
#  {'business_name': 'ANELACE COFFEE',
#   'address': '2402 CENTRAL AVE NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 90,
#   'neighborhood': 'Holland',
#   'latitude': Decimal('45.01243'),
#   'longitude': Decimal('-93.24788000000001')},
#  {'business_name': 'ANELACE COFFEE',
#   'address': '2402 CENTRAL AVE NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Holland',
#   'latitude': Decimal('45.01243'),
#   'longitude': Decimal('-93.24788000000001')},
#  {'business_name': 'ANGEL FOOD',
#   'address': '86 9TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 88,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97482'),
#   'longitude': Decimal('-93.27266999999999')},
#  {'business_name': 'ANGEL FOOD',
#   'address': '86 9TH ST S',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97482'),
#   'longitude': Decimal('-93.27266999999999')},
#  {'business_name': 'ANGRY CATFISH BICYCLE',
#   'address': '4208 28TH AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 88,
#   'neighborhood': 'Standish',
#   'latitude': Decimal('44.926520000000004'),
#   'longitude': Decimal('-93.2325')},
#  {'business_name': 'ANNIES KITTY CAT KLUB',
#   'address': '313 14TH AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98005'),
#   'longitude': Decimal('-93.23656')},
#  {'business_name': 'ANNIES KITTY CAT KLUB',
#   'address': '313 14TH AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 90,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98005'),
#   'longitude': Decimal('-93.23656')},
#  {'business_name': 'ANNIES KITTY CAT KLUB',
#   'address': '313 14TH AVE SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98005'),
#   'longitude': Decimal('-93.23656')},
#  {'business_name': 'ANNIES KITTY CAT KLUB',
#   'address': '313 14TH AVE SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98005'),
#   'longitude': Decimal('-93.23656')},
#  {'business_name': "APPLEBEE'S NEIGHBORHOOD GRILL & BAR",
#   'address': '615 WASHINGTON AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'University of Minnesota',
#   'latitude': Decimal('44.97419'),
#   'longitude': Decimal('-93.22952')},
#  {'business_name': "APPLEBEE'S NEIGHBORHOOD GRILL & BAR",
#   'address': '615 WASHINGTON AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'University of Minnesota',
#   'latitude': Decimal('44.97419'),
#   'longitude': Decimal('-93.22952')},
#  {'business_name': 'AREZZO RISTORANTE',
#   'address': '5057 FRANCE AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 88,
#   'neighborhood': 'Fulton',
#   'latitude': Decimal('44.91098'),
#   'longitude': Decimal('-93.32866')},
#  {'business_name': 'AREZZO RISTORANTE',
#   'address': '5057 FRANCE AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Fulton',
#   'latitude': Decimal('44.91098'),
#   'longitude': Decimal('-93.32866')},
#  {'business_name': 'AGRA CULTURE',
#   'address': '2939 GIRARD AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.94885'),
#   'longitude': Decimal('-93.29663000000001')},
#  {'business_name': 'ARIA AT THE JEUNE LUNE',
#   'address': '105 1ST ST N',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'North Loop',
#   'latitude': Decimal('44.98471'),
#   'longitude': Decimal('-93.26873')},
#  {'business_name': 'CAFFETTO',
#   'address': '708 22ND ST W',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.96116'),
#   'longitude': Decimal('-93.28845')},
#  {'business_name': 'CAFFETTO',
#   'address': '708 22ND ST W',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.96116'),
#   'longitude': Decimal('-93.28845')},
#  {'business_name': 'CAFFREYS DELI & SUBS',
#   'address': '3008 LYNDALE AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Hawthorne',
#   'latitude': Decimal('45.01102'),
#   'longitude': Decimal('-93.28755')},
#  {'business_name': 'CAFFREYS DELI & SUBS',
#   'address': '3008 LYNDALE AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Hawthorne',
#   'latitude': Decimal('45.01102'),
#   'longitude': Decimal('-93.28755')},
#  {'business_name': 'CAFFREYS DELI & SUBS',
#   'address': '3008 LYNDALE AVE S',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Hawthorne',
#   'latitude': Decimal('45.01102'),
#   'longitude': Decimal('-93.28755')},
#  {'business_name': 'CAFFREYS DELI & SUBS',
#   'address': '3008 LYNDALE AVE S',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Hawthorne',
#   'latitude': Decimal('45.01102'),
#   'longitude': Decimal('-93.28755')},
#  {'business_name': 'CAIRO GRILL',
#   'address': '1922 CHICAGO AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 76,
#   'neighborhood': 'Ventura Village',
#   'latitude': Decimal('44.96315'),
#   'longitude': Decimal('-93.26295999999999')},
#  {'business_name': 'CAIRO GRILL',
#   'address': '1922 CHICAGO AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 90,
#   'neighborhood': 'Ventura Village',
#   'latitude': Decimal('44.96315'),
#   'longitude': Decimal('-93.26295999999999')},
#  {'business_name': 'CAIRO GRILL',
#   'address': '1922 CHICAGO AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 94,
#   'neighborhood': 'Ventura Village',
#   'latitude': Decimal('44.96315'),
#   'longitude': Decimal('-93.26295999999999')},
#  {'business_name': 'CAIRO GRILL',
#   'address': '1922 CHICAGO AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Ventura Village',
#   'latitude': Decimal('44.96315'),
#   'longitude': Decimal('-93.26295999999999')},
#  {'business_name': 'CALIS VIETNAMESE RESTAURANT',
#   'address': '648 BROADWAY ST NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 76,
#   'neighborhood': 'St. Anthony East',
#   'latitude': Decimal('44.998509999999996'),
#   'longitude': Decimal('-93.25589000000001')},
#  {'business_name': 'CALIS VIETNAMESE RESTAURANT',
#   'address': '648 BROADWAY ST NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 80,
#   'neighborhood': 'St. Anthony East',
#   'latitude': Decimal('44.998509999999996'),
#   'longitude': Decimal('-93.25589000000001')},
#  {'business_name': 'CALIS VIETNAMESE RESTAURANT',
#   'address': '648 BROADWAY ST NE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 86,
#   'neighborhood': 'St. Anthony East',
#   'latitude': Decimal('44.998509999999996'),
#   'longitude': Decimal('-93.25589000000001')},
#  {'business_name': 'CALIS VIETNAMESE RESTAURANT',
#   'address': '648 BROADWAY ST NE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'St. Anthony East',
#   'latitude': Decimal('44.998509999999996'),
#   'longitude': Decimal('-93.25589000000001')},
#  {'business_name': 'CALIS VIETNAMESE RESTAURANT',
#   'address': '648 BROADWAY ST NE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'St. Anthony East',
#   'latitude': Decimal('44.998509999999996'),
#   'longitude': Decimal('-93.25589000000001')},
#  {'business_name': 'CAMDEN TAVERN & GRILL',
#   'address': '4601 LYNDALE AVE N',
#   'inspection_type': 'Routine',
#   'inspection_score': 86,
#   'neighborhood': 'Lind - Bohanon',
#   'latitude': Decimal('45.03872'),
#   'longitude': Decimal('-93.28788')},
#  {'business_name': 'CAMDEN TAVERN & GRILL',
#   'address': '4601 LYNDALE AVE N',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Lind - Bohanon',
#   'latitude': Decimal('45.03872'),
#   'longitude': Decimal('-93.28788')},
#  {'business_name': 'CAMDEN TAVERN & GRILL',
#   'address': '4601 LYNDALE AVE N',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 94,
#   'neighborhood': 'Lind - Bohanon',
#   'latitude': Decimal('45.03872'),
#   'longitude': Decimal('-93.28788')},
#  {'business_name': 'CAMDEN TAVERN & GRILL',
#   'address': '4601 LYNDALE AVE N',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Lind - Bohanon',
#   'latitude': Decimal('45.03872'),
#   'longitude': Decimal('-93.28788')},
#  {'business_name': 'CAMDEN TAVERN & GRILL',
#   'address': '4601 LYNDALE AVE N',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Lind - Bohanon',
#   'latitude': Decimal('45.03872'),
#   'longitude': Decimal('-93.28788')},
#  {'business_name': 'CAMDI RESTAURANTS',
#   'address': '1325 4TH ST SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 84,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98097'),
#   'longitude': Decimal('-93.23602')},
#  {'business_name': 'CAMDI RESTAURANTS',
#   'address': '1325 4TH ST SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 82,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98097'),
#   'longitude': Decimal('-93.23602')},
#  {'business_name': 'CAMDI RESTAURANTS',
#   'address': '1325 4TH ST SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98097'),
#   'longitude': Decimal('-93.23602')},
#  {'business_name': 'CAMDI RESTAURANTS',
#   'address': '1325 4TH ST SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98097'),
#   'longitude': Decimal('-93.23602')},
#  {'business_name': 'CAMDI RESTAURANTS',
#   'address': '1325 4TH ST SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 92,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98097'),
#   'longitude': Decimal('-93.23602')},
#  {'business_name': 'CAMPUS CLUB OF THE UNIV OF MN',
#   'address': '300 WASHINGTON AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'University of Minnesota',
#   'latitude': Decimal('44.97302'),
#   'longitude': Decimal('-93.23473')},
#  {'business_name': 'CANDYLAND',
#   'address': '811 LASALLE AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97592'),
#   'longitude': Decimal('-93.27444')},
#  {'business_name': 'CANDYLAND',
#   'address': '27 7TH ST S #MAIN FLOOR',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.977140000000006'),
#   'longitude': Decimal('-93.2744')},
#  {'business_name': 'CANDYLAND',
#   'address': '27 7TH ST S #MAIN FLOOR',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.977140000000006'),
#   'longitude': Decimal('-93.2744')},
#  {'business_name': 'CANTEEN',
#   'address': '3255 BRYANT AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'South Uptown',
#   'latitude': Decimal('44.94305'),
#   'longitude': Decimal('-93.29034')},
#  {'business_name': 'CAPITAL GRILLE',
#   'address': '801 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.976620000000004'),
#   'longitude': Decimal('-93.27574')},
#  {'business_name': 'CAPITAL GRILLE',
#   'address': '801 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.976620000000004'),
#   'longitude': Decimal('-93.27574')},
#  {'business_name': 'CARAVELLE-PHO 79 RESTAURANT',
#   'address': '2529 NICOLLET AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.95633'),
#   'longitude': Decimal('-93.27747')},
#  {'business_name': 'CARAVELLE-PHO 79 RESTAURANT',
#   'address': '2529 NICOLLET AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 90,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.95633'),
#   'longitude': Decimal('-93.27747')},
#  {'business_name': 'CARAVELLE-PHO 79 RESTAURANT',
#   'address': '2529 NICOLLET AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.95633'),
#   'longitude': Decimal('-93.27747')},
#  {'business_name': "CARBONE'S PIZZERIA",
#   'address': '3722 50TH ST W',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Fulton',
#   'latitude': Decimal('44.912729999999996'),
#   'longitude': Decimal('-93.32741')},
#  {'business_name': "CARBONE'S PIZZERIA",
#   'address': '3722 50TH ST W',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Fulton',
#   'latitude': Decimal('44.912729999999996'),
#   'longitude': Decimal('-93.32741')},
#  {'business_name': "CARBONE'S PIZZERIA",
#   'address': '3722 50TH ST W',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Fulton',
#   'latitude': Decimal('44.912729999999996'),
#   'longitude': Decimal('-93.32741')},
#  {'business_name': 'CARBONES PIZZA ON THE PARKWAY',
#   'address': '4705 CEDAR AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 90,
#   'neighborhood': 'Ericsson',
#   'latitude': Decimal('44.917559999999995'),
#   'longitude': Decimal('-93.2469')},
#  {'business_name': 'CARBONES PIZZA ON THE PARKWAY',
#   'address': '4705 CEDAR AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Ericsson',
#   'latitude': Decimal('44.917559999999995'),
#   'longitude': Decimal('-93.2469')},
#  {'business_name': 'CARBONES PIZZA ON THE PARKWAY',
#   'address': '4705 CEDAR AVE S',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Ericsson',
#   'latitude': Decimal('44.917559999999995'),
#   'longitude': Decimal('-93.2469')},
#  {'business_name': 'CARDINAL BAR',
#   'address': '2920 38TH ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Linden Hills',
#   'latitude': Decimal('44.934329999999996'),
#   'longitude': Decimal('-93.31729')},
#  {'business_name': 'CARDINAL BAR',
#   'address': '2920 38TH ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 84,
#   'neighborhood': 'Linden Hills',
#   'latitude': Decimal('44.934329999999996'),
#   'longitude': Decimal('-93.31729')},
#  {'business_name': 'DOGWOOD COFFEE',
#   'address': '3027 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'South Uptown',
#   'latitude': Decimal('44.94743'),
#   'longitude': Decimal('-93.29732')},
#  {'business_name': 'DOGWOOD COFFEE',
#   'address': '3027 HENNEPIN AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'South Uptown',
#   'latitude': Decimal('44.94743'),
#   'longitude': Decimal('-93.29732')},
#  {'business_name': 'DOGWOOD COFFEE CO',
#   'address': '4023 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 88,
#   'neighborhood': 'Cooper',
#   'latitude': Decimal('44.94808'),
#   'longitude': Decimal('-93.2143')},
#  {'business_name': 'DOGWOOD COFFEE CO',
#   'address': '4023 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 88,
#   'neighborhood': 'Cooper',
#   'latitude': Decimal('44.94808'),
#   'longitude': Decimal('-93.2143')},
#  {'business_name': 'DOGWOOD COFFEE CO',
#   'address': '4023 LAKE ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Cooper',
#   'latitude': Decimal('44.94808'),
#   'longitude': Decimal('-93.2143')},
#  {'business_name': 'DOGWOOD COFFEE CO',
#   'address': '4023 LAKE ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Cooper',
#   'latitude': Decimal('44.94808'),
#   'longitude': Decimal('-93.2143')},
#  {'business_name': 'DOMINGUEZ FAMILY RESTAURANT',
#   'address': '3313 50TH ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Keewaydin',
#   'latitude': Decimal('44.91231'),
#   'longitude': Decimal('-93.2236')},
#  {'business_name': 'DOMINGUEZ FAMILY RESTAURANT',
#   'address': '3313 50TH ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Keewaydin',
#   'latitude': Decimal('44.91231'),
#   'longitude': Decimal('-93.2236')},
#  {'business_name': 'DOMINOS PIZZA #1901',
#   'address': '215 OAK ST SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'Prospect Park - East River Road',
#   'latitude': Decimal('44.97418'),
#   'longitude': Decimal('-93.22666')},
#  {'business_name': 'DOMINOS PIZZA #1901',
#   'address': '215 OAK ST SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Prospect Park - East River Road',
#   'latitude': Decimal('44.97418'),
#   'longitude': Decimal('-93.22666')},
#  {'business_name': 'DOMINOS PIZZA #1908',
#   'address': '1901 JOHNSON ST NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Windom Park',
#   'latitude': Decimal('45.00799'),
#   'longitude': Decimal('-93.2368')},
#  {'business_name': 'DOMINOS PIZZA #1918',
#   'address': '1113 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.9748'),
#   'longitude': Decimal('-93.27937')},
#  {'business_name': 'DOMINOS PIZZA #1923',
#   'address': '5957 PENN AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 90,
#   'neighborhood': 'Armatage',
#   'latitude': Decimal('44.89476'),
#   'longitude': Decimal('-93.30829')},
#  {'business_name': 'DOMINOS PIZZA #1923',
#   'address': '5957 PENN AVE S',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Armatage',
#   'latitude': Decimal('44.89476'),
#   'longitude': Decimal('-93.30829')},
#  {'business_name': 'DOMINOS PIZZA #1945',
#   'address': '4552 BLOOMINGTON AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Northrop',
#   'latitude': Decimal('44.919909999999994'),
#   'longitude': Decimal('-93.2528')},
#  {'business_name': 'DOMINOS PIZZA #1947',
#   'address': '2441 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.95758'),
#   'longitude': Decimal('-93.2948')},
#  {'business_name': 'DOMINOS PIZZA',
#   'address': '4737 HIAWATHA AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Hiawatha',
#   'latitude': Decimal('44.917640000000006'),
#   'longitude': Decimal('-93.21581')},
#  {'business_name': 'DOMO GASTRO',
#   'address': '1032 3RD AVE NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 86,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.99463'),
#   'longitude': Decimal('-93.24784')},
#  {'business_name': 'DOMO GASTRO',
#   'address': '1032 3RD AVE NE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.99463'),
#   'longitude': Decimal('-93.24784')},
#  {'business_name': 'DOUBLETREE HOTEL',
#   'address': '1101 LASALLE AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97314'),
#   'longitude': Decimal('-93.2768')},
#  {'business_name': 'DOUBLETREE HOTEL',
#   'address': '1101 LASALLE AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97314'),
#   'longitude': Decimal('-93.2768')},
#  {'business_name': 'DOWNTOWN CABARET',
#   'address': '115 4TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 84,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.978609999999996'),
#   'longitude': Decimal('-93.2679')},
#  {'business_name': 'DOWNTOWN CABARET',
#   'address': '115 4TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.978609999999996'),
#   'longitude': Decimal('-93.2679')},
#  {'business_name': 'DOWNTOWN CABARET',
#   'address': '115 4TH ST S',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.978609999999996'),
#   'longitude': Decimal('-93.2679')},
#  {'business_name': 'DOWNTOWN CABARET',
#   'address': '115 4TH ST S',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.978609999999996'),
#   'longitude': Decimal('-93.2679')},
#  {'business_name': 'DOWNTOWN MARKET',
#   'address': '150 2ND AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.98222'),
#   'longitude': Decimal('-93.26498000000001')},
#  {'business_name': 'DOWNTOWN MARKET',
#   'address': '150 2ND AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.98222'),
#   'longitude': Decimal('-93.26498000000001')},
#  {'business_name': 'DOWNTOWN RESIDENCE INN',
#   'address': '45 8TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97592'),
#   'longitude': Decimal('-93.27444')},
#  {'business_name': 'DRAKE HOTEL',
#   'address': '416 10TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97161'),
#   'longitude': Decimal('-93.26796')},
#  {'business_name': 'DRAKE HOTEL',
#   'address': '416 10TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97161'),
#   'longitude': Decimal('-93.26796')},
#  {'business_name': 'LAST CALL',
#   'address': '26 5TH ST N',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.980470000000004'),
#   'longitude': Decimal('-93.27325')},
#  {'business_name': 'LAST CALL',
#   'address': '26 5TH ST N',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.980470000000004'),
#   'longitude': Decimal('-93.27325')},
#  {'business_name': 'DREAMGIRLS',
#   'address': '12 5TH ST N',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.98012'),
#   'longitude': Decimal('-93.27275999999999')},
#  {'business_name': 'DRIFTWOOD',
#   'address': '4415 NICOLLET AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'King Field',
#   'latitude': Decimal('44.922740000000005'),
#   'longitude': Decimal('-93.27754')},
#  {'business_name': 'DRIFTWOOD',
#   'address': '4415 NICOLLET AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'King Field',
#   'latitude': Decimal('44.922740000000005'),
#   'longitude': Decimal('-93.27754')},
#  {'business_name': 'DRIFTWOOD',
#   'address': '4415 NICOLLET AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'King Field',
#   'latitude': Decimal('44.922740000000005'),
#   'longitude': Decimal('-93.27754')},
#  {'business_name': 'DRIFTWOOD',
#   'address': '4415 NICOLLET AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'King Field',
#   'latitude': Decimal('44.922740000000005'),
#   'longitude': Decimal('-93.27754')},
#  {'business_name': 'GOOD DEAL ORIENTAL FOODS',
#   'address': '1800 LOWRY AVE N',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Folwell',
#   'latitude': Decimal('45.013490000000004'),
#   'longitude': Decimal('-93.30227')},
#  {'business_name': 'GOOD DEAL ORIENTAL FOODS',
#   'address': '1800 LOWRY AVE N',
#   'inspection_type': 'Routine',
#   'inspection_score': 78,
#   'neighborhood': 'Folwell',
#   'latitude': Decimal('45.013490000000004'),
#   'longitude': Decimal('-93.30227')},
#  {'business_name': 'GOOD DEAL ORIENTAL FOODS',
#   'address': '1800 LOWRY AVE N',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Folwell',
#   'latitude': Decimal('45.013490000000004'),
#   'longitude': Decimal('-93.30227')},
#  {'business_name': 'GOOD TO GO',
#   'address': '200 6TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.9769'),
#   'longitude': Decimal('-93.26762')},
#  {'business_name': 'GOOD TO GO',
#   'address': '200 6TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.9769'),
#   'longitude': Decimal('-93.26762')},
#  {'business_name': 'GORDITAS EL GORDO',
#   'address': '207 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Central',
#   'latitude': Decimal('44.94806'),
#   'longitude': Decimal('-93.27364')},
#  {'business_name': 'GORDITAS EL GORDO',
#   'address': '207 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Central',
#   'latitude': Decimal('44.94806'),
#   'longitude': Decimal('-93.27364')},
#  {'business_name': 'GORKHA PALACE',
#   'address': '23 4TH ST NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Nicollet Island - East Bank',
#   'latitude': Decimal('44.989290000000004'),
#   'longitude': Decimal('-93.25498')},
#  {'business_name': 'GORKHA PALACE',
#   'address': '23 4TH ST NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Nicollet Island - East Bank',
#   'latitude': Decimal('44.989290000000004'),
#   'longitude': Decimal('-93.25498')},
#  {'business_name': 'GORKHA PALACE',
#   'address': '23 4TH ST NE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 90,
#   'neighborhood': 'Nicollet Island - East Bank',
#   'latitude': Decimal('44.989290000000004'),
#   'longitude': Decimal('-93.25498')},
#  {'business_name': 'GORKHA PALACE',
#   'address': '23 4TH ST NE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Nicollet Island - East Bank',
#   'latitude': Decimal('44.989290000000004'),
#   'longitude': Decimal('-93.25498')},
#  {'business_name': 'GRAND OLE CREAMERY',
#   'address': '4737 CEDAR AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Ericsson',
#   'latitude': Decimal('44.91677'),
#   'longitude': Decimal('-93.2469')},
#  {'business_name': 'GRASS ROOTS GOURMET',
#   'address': '920 LAKE ST E #130',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Midtown Phillips',
#   'latitude': Decimal('44.94931'),
#   'longitude': Decimal('-93.26076')},
#  {'business_name': 'GRASS ROOTS GOURMET',
#   'address': '920 LAKE ST E #130',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Midtown Phillips',
#   'latitude': Decimal('44.94931'),
#   'longitude': Decimal('-93.26076')},
#  {'business_name': 'GREAT DRAGON',
#   'address': '1916 CHICAGO AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 76,
#   'neighborhood': 'Ventura Village',
#   'latitude': Decimal('44.96315'),
#   'longitude': Decimal('-93.26295999999999')},
#  {'business_name': 'GREAT DRAGON',
#   'address': '1916 CHICAGO AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 82,
#   'neighborhood': 'Ventura Village',
#   'latitude': Decimal('44.96315'),
#   'longitude': Decimal('-93.26295999999999')},
#  {'business_name': 'GREAT DRAGON',
#   'address': '1916 CHICAGO AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Ventura Village',
#   'latitude': Decimal('44.96315'),
#   'longitude': Decimal('-93.26295999999999')},
#  {'business_name': 'GREAT HARVEST BREAD CO.',
#   'address': '4314 UPTON AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 90,
#   'neighborhood': 'Linden Hills',
#   'latitude': Decimal('44.92399'),
#   'longitude': Decimal('-93.31524')},
#  {'business_name': 'GREAT HARVEST BREAD CO.',
#   'address': '4314 UPTON AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Linden Hills',
#   'latitude': Decimal('44.92399'),
#   'longitude': Decimal('-93.31524')},
#  {'business_name': 'GREAT HARVEST BREAD CO.',
#   'address': '4314 UPTON AVE S',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Linden Hills',
#   'latitude': Decimal('44.92399'),
#   'longitude': Decimal('-93.31524')},
#  {'business_name': 'FAT DUCK',
#   'address': '4515 FRANCE AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'Linden Hills',
#   'latitude': Decimal('44.92112'),
#   'longitude': Decimal('-93.32874')},
#  {'business_name': 'FAT DUCK',
#   'address': '4515 FRANCE AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Linden Hills',
#   'latitude': Decimal('44.92112'),
#   'longitude': Decimal('-93.32874')},
#  {'business_name': 'FAT DUCK',
#   'address': '4515 FRANCE AVE S',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Linden Hills',
#   'latitude': Decimal('44.92112'),
#   'longitude': Decimal('-93.32874')},
#  {'business_name': 'GREEK GRILL & CAFE',
#   'address': '625 MARQUETTE AVE #236',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.976420000000005'),
#   'longitude': Decimal('-93.27017')},
#  {'business_name': 'GREEK GRILL & CAFE',
#   'address': '625 MARQUETTE AVE #236',
#   'inspection_type': 'Routine',
#   'inspection_score': 82,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.976420000000005'),
#   'longitude': Decimal('-93.27017')},
#  {'business_name': 'GREEK GRILL & CAFE',
#   'address': '625 MARQUETTE AVE #236',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 92,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.976420000000005'),
#   'longitude': Decimal('-93.27017')},
#  {'business_name': 'KENWOOD ISLES',
#   'address': '1425 28TH ST W',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'East Isles',
#   'latitude': Decimal('44.95172'),
#   'longitude': Decimal('-93.2993')},
#  {'business_name': 'KENWOOD ISLES',
#   'address': '1425 28TH ST W',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'East Isles',
#   'latitude': Decimal('44.95172'),
#   'longitude': Decimal('-93.2993')},
#  {'business_name': 'KENWOOD ISLES',
#   'address': '1425 28TH ST W',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'East Isles',
#   'latitude': Decimal('44.95172'),
#   'longitude': Decimal('-93.2993')},
#  {'business_name': 'KEYS AT THE FOSHAY BAR & GRILL',
#   'address': '114 9TH ST S #FOSHAY TOW',
#   'inspection_type': 'Routine',
#   'inspection_score': 88,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97448'),
#   'longitude': Decimal('-93.2718')},
#  {'business_name': 'KEYS AT THE FOSHAY BAR & GRILL',
#   'address': '114 9TH ST S #FOSHAY TOW',
#   'inspection_type': 'Routine',
#   'inspection_score': 72,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97448'),
#   'longitude': Decimal('-93.2718')},
#  {'business_name': 'KEYS AT THE FOSHAY BAR & GRILL',
#   'address': '114 9TH ST S #FOSHAY TOW',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97448'),
#   'longitude': Decimal('-93.2718')},
#  {'business_name': 'KEYS AT THE FOSHAY BAR & GRILL',
#   'address': '114 9TH ST S #FOSHAY TOW',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97448'),
#   'longitude': Decimal('-93.2718')},
#  {'business_name': 'KHUNNAI THAI CUISINE',
#   'address': '2523 NICOLLET AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.95649'),
#   'longitude': Decimal('-93.27747')},
#  {'business_name': 'KHUNNAI THAI CUISINE',
#   'address': '2523 NICOLLET AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.95649'),
#   'longitude': Decimal('-93.27747')},
#  {'business_name': "KIERAN'S IRISH PUB FIRST AVENUE",
#   'address': '600 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 86,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.989470000000004'),
#   'longitude': Decimal('-93.2513')},
#  {'business_name': "KIERAN'S IRISH PUB FIRST AVENUE",
#   'address': '600 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 90,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.989470000000004'),
#   'longitude': Decimal('-93.2513')},
#  {'business_name': "KIERAN'S IRISH PUB FIRST AVENUE",
#   'address': '600 HENNEPIN AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 92,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.989470000000004'),
#   'longitude': Decimal('-93.2513')},
#  {'business_name': "KIERAN'S IRISH PUB FIRST AVENUE",
#   'address': '600 HENNEPIN AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 90,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.989470000000004'),
#   'longitude': Decimal('-93.2513')},
#  {'business_name': "KIERAN'S IRISH PUB FIRST AVENUE",
#   'address': '600 HENNEPIN AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.989470000000004'),
#   'longitude': Decimal('-93.2513')},
#  {'business_name': "KIERAN'S IRISH PUB FIRST AVENUE",
#   'address': '600 HENNEPIN AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.989470000000004'),
#   'longitude': Decimal('-93.2513')},
#  {'business_name': 'KIKU BISTRO',
#   'address': '2819 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 82,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.9512'),
#   'longitude': Decimal('-93.29786999999999')},
#  {'business_name': 'KIKU BISTRO',
#   'address': '2819 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.9512'),
#   'longitude': Decimal('-93.29786999999999')},
#  {'business_name': 'KIKU BISTRO',
#   'address': '2819 HENNEPIN AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.9512'),
#   'longitude': Decimal('-93.29786999999999')},
#  {'business_name': 'KINDEE',
#   'address': '719 2ND ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Downtown East',
#   'latitude': Decimal('44.977959999999996'),
#   'longitude': Decimal('-93.25735')},
#  {'business_name': 'KINDEE',
#   'address': '719 2ND ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 86,
#   'neighborhood': 'Downtown East',
#   'latitude': Decimal('44.977959999999996'),
#   'longitude': Decimal('-93.25735')},
#  {'business_name': 'KINHDO RESTAURANT',
#   'address': '2755 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 90,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.95213'),
#   'longitude': Decimal('-93.29785')},
#  {'business_name': 'KINHDO RESTAURANT',
#   'address': '2755 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.95213'),
#   'longitude': Decimal('-93.29785')},
#  {'business_name': 'KINHDO RESTAURANT',
#   'address': '2755 HENNEPIN AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.95213'),
#   'longitude': Decimal('-93.29785')},
#  {'business_name': 'KITSU',
#   'address': '1540 NEW BRIGHTON BLVD',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Northeast Park',
#   'latitude': Decimal('45.004870000000004'),
#   'longitude': Decimal('-93.23176')},
#  {'business_name': 'KITSU',
#   'address': '1540 NEW BRIGHTON BLVD',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Northeast Park',
#   'latitude': Decimal('45.004870000000004'),
#   'longitude': Decimal('-93.23176')},
#  {'business_name': 'KOKAPELLI',
#   'address': '100 6TH ST N',
#   'inspection_type': 'Routine',
#   'inspection_score': 86,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.98041'),
#   'longitude': Decimal('-93.27526999999999')},
#  {'business_name': 'KOKAPELLI',
#   'address': '100 6TH ST N',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.98041'),
#   'longitude': Decimal('-93.27526999999999')},
#  {'business_name': 'KOKAPELLI',
#   'address': '100 6TH ST N',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.98041'),
#   'longitude': Decimal('-93.27526999999999')},
#  {'business_name': 'KOWALSKIS LYNDALE MARKETS',
#   'address': '5327 LYNDALE AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Tangletown',
#   'latitude': Decimal('44.905590000000004'),
#   'longitude': Decimal('-93.28761')},
#  {'business_name': 'KOWALSKIS LYNDALE MARKETS',
#   'address': '5327 LYNDALE AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Tangletown',
#   'latitude': Decimal('44.905590000000004'),
#   'longitude': Decimal('-93.28761')},
#  {'business_name': 'KOWALSKIS PARKVIEW MARKET',
#   'address': '5615 CHICAGO AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Diamond Lake',
#   'latitude': Decimal('44.90088'),
#   'longitude': Decimal('-93.26233')},
#  {'business_name': 'KOWALSKIS PARKVIEW MARKET',
#   'address': '5615 CHICAGO AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Diamond Lake',
#   'latitude': Decimal('44.90088'),
#   'longitude': Decimal('-93.26233')},
#  {'business_name': 'KOWALSKIS UPTOWN MARKET',
#   'address': '2440 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'East Isles',
#   'latitude': Decimal('44.95767'),
#   'longitude': Decimal('-93.29608')},
#  {'business_name': 'KOWALSKIS UPTOWN MARKET',
#   'address': '2440 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'East Isles',
#   'latitude': Decimal('44.95767'),
#   'longitude': Decimal('-93.29608')},
#  {'business_name': 'KOWLOON RESTAURANT',
#   'address': '935 WASHINGTON AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 60,
#   'neighborhood': 'Prospect Park - East River Road',
#   'latitude': Decimal('44.97394'),
#   'longitude': Decimal('-93.22448')},
#  {'business_name': 'KOWLOON RESTAURANT',
#   'address': '935 WASHINGTON AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Prospect Park - East River Road',
#   'latitude': Decimal('44.97394'),
#   'longitude': Decimal('-93.22448')},
#  {'business_name': 'KOWLOON RESTAURANT',
#   'address': '935 WASHINGTON AVE SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Prospect Park - East River Road',
#   'latitude': Decimal('44.97394'),
#   'longitude': Decimal('-93.22448')},
#  {'business_name': 'KOWLOON RESTAURANT',
#   'address': '935 WASHINGTON AVE SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 90,
#   'neighborhood': 'Prospect Park - East River Road',
#   'latitude': Decimal('44.97394'),
#   'longitude': Decimal('-93.22448')},
#  {'business_name': 'KOWLOON RESTAURANT',
#   'address': '935 WASHINGTON AVE SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 94,
#   'neighborhood': 'Prospect Park - East River Road',
#   'latitude': Decimal('44.97394'),
#   'longitude': Decimal('-93.22448')},
#  {'business_name': 'MERCADO CENTRAL',
#   'address': '1515 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.94793'),
#   'longitude': Decimal('-93.25289000000001')},
#  {'business_name': 'MERCADO CENTRAL',
#   'address': '1515 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 78,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.94793'),
#   'longitude': Decimal('-93.25289000000001')},
#  {'business_name': 'LA LOMA TAMALES',
#   'address': '1515 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.94793'),
#   'longitude': Decimal('-93.25289000000001')},
#  {'business_name': 'LA LOMA TAMALES',
#   'address': '1515 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.94793'),
#   'longitude': Decimal('-93.25289000000001')},
#  {'business_name': 'REYNA DE LOS JUGOS',
#   'address': '1515 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.94793'),
#   'longitude': Decimal('-93.25289000000001')},
#  {'business_name': 'REYNA DE LOS JUGOS',
#   'address': '1515 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.94793'),
# ...
#   'longitude': Decimal('-93.31405')},
#  {'business_name': 'TINY DINER',
#   'address': '1024 38TH ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 78,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.93439'),
#   'longitude': Decimal('-93.25907')},
#  {'business_name': 'TINY DINER',
#   'address': '1024 38TH ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 88,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.93439'),
#   'longitude': Decimal('-93.25907')},
#  {'business_name': 'TINY DINER',
#   'address': '1024 38TH ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.93439'),
#   'longitude': Decimal('-93.25907')},
#  {'business_name': 'TINY DINER',
#   'address': '1024 38TH ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 88,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.93439'),
#   'longitude': Decimal('-93.25907')},
#  {'business_name': 'TINY DINER',
#   'address': '1024 38TH ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.93439'),
#   'longitude': Decimal('-93.25907')},
#  {'business_name': 'MAMA SHEILA SOUL FOOD KITCHEN',
#   'address': '3744 BLOOMINGTON AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 58,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.934290000000004'),
#   'longitude': Decimal('-93.25279')},
#  {'business_name': 'MAMA SHEILA SOUL FOOD KITCHEN',
#   'address': '3744 BLOOMINGTON AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 80,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.934290000000004'),
#   'longitude': Decimal('-93.25279')},
#  {'business_name': 'MAMA SHEILA SOUL FOOD KITCHEN',
#   'address': '3744 BLOOMINGTON AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 92,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.934290000000004'),
#   'longitude': Decimal('-93.25279')},
#  {'business_name': 'MAMA SHEILA SOUL FOOD KITCHEN',
#   'address': '3744 BLOOMINGTON AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.934290000000004'),
#   'longitude': Decimal('-93.25279')},
#  {'business_name': 'MAMA SHEILA SOUL FOOD KITCHEN',
#   'address': '3744 BLOOMINGTON AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 90,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.934290000000004'),
#   'longitude': Decimal('-93.25279')},
#  {'business_name': 'MAMA SHEILA SOUL FOOD KITCHEN',
#   'address': '3744 BLOOMINGTON AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.934290000000004'),
#   'longitude': Decimal('-93.25279')},
#  {'business_name': "MARIA'S RESTAURANTE",
#   'address': '1515 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.94793'),
#   'longitude': Decimal('-93.25289000000001')},
#  {'business_name': "MARIA'S RESTAURANTE",
#   'address': '1515 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Powderhorn Park',
#   'latitude': Decimal('44.94793'),
#   'longitude': Decimal('-93.25289000000001')},
#  {'business_name': 'TENANT RESTAURANT',
#   'address': '4300 BRYANT AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'East Harriet',
#   'latitude': Decimal('44.924859999999995'),
#   'longitude': Decimal('-93.29109')},
#  {'business_name': 'THE CAFE',
#   'address': '3033 EXCELSIOR BLVD',
#   'inspection_type': 'Routine',
#   'inspection_score': 86,
#   'neighborhood': 'West Calhoun',
#   'latitude': Decimal('44.94748'),
#   'longitude': Decimal('-93.31844')},
#  {'business_name': 'THE CAFE',
#   'address': '3033 EXCELSIOR BLVD',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'West Calhoun',
#   'latitude': Decimal('44.94748'),
#   'longitude': Decimal('-93.31844')},
#  {'business_name': 'HOT PLATE 2.0',
#   'address': '5204 BLOOMINGTON AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'Hale',
#   'latitude': Decimal('44.90863'),
#   'longitude': Decimal('-93.25284')},
#  {'business_name': 'HOT PLATE 2.0',
#   'address': '5204 BLOOMINGTON AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Hale',
#   'latitude': Decimal('44.90863'),
#   'longitude': Decimal('-93.25284')},
#  {'business_name': 'HOT PLATE 2.0',
#   'address': '5204 BLOOMINGTON AVE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Hale',
#   'latitude': Decimal('44.90863'),
#   'longitude': Decimal('-93.25284')},
#  {'business_name': 'LE POT',
#   'address': '507 14TH AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 84,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98232'),
#   'longitude': Decimal('-93.2356')},
#  {'business_name': 'LE POT',
#   'address': '507 14TH AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 86,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98232'),
#   'longitude': Decimal('-93.2356')},
#  {'business_name': 'LE POT',
#   'address': '507 14TH AVE SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98232'),
#   'longitude': Decimal('-93.2356')},
#  {'business_name': 'LE POT',
#   'address': '507 14TH AVE SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.98232'),
#   'longitude': Decimal('-93.2356')},
#  {'business_name': 'GALEEYR COFFEE',
#   'address': '2910 PILLSBURY AVE #302',
#   'inspection_type': 'Routine',
#   'inspection_score': 70,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.949690000000004'),
#   'longitude': Decimal('-93.2821')},
#  {'business_name': 'GALEEYR COFFEE',
#   'address': '2910 PILLSBURY AVE #302',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 94,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.949690000000004'),
#   'longitude': Decimal('-93.2821')},
#  {'business_name': 'GALEEYR COFFEE',
#   'address': '2910 PILLSBURY AVE #302',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.949690000000004'),
#   'longitude': Decimal('-93.2821')},
#  {'business_name': 'GALEEYR COFFEE',
#   'address': '2910 PILLSBURY AVE #302',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 84,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.949690000000004'),
#   'longitude': Decimal('-93.2821')},
#  {'business_name': 'GALEEYR COFFEE',
#   'address': '2910 PILLSBURY AVE #302',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Whittier',
#   'latitude': Decimal('44.949690000000004'),
#   'longitude': Decimal('-93.2821')},
#  {'business_name': 'BRAVA COFFEE AND FOODS',
#   'address': '2021 HENNEPIN AVE E',
#   'inspection_type': 'Routine',
#   'inspection_score': 74,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.962109999999996'),
#   'longitude': Decimal('-93.29142')},
#  {'business_name': 'BRAVA COFFEE AND FOODS',
#   'address': '2021 HENNEPIN AVE E',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.962109999999996'),
#   'longitude': Decimal('-93.29142')},
#  {'business_name': 'BRAVA COFFEE AND FOODS',
#   'address': '2021 HENNEPIN AVE E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 92,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.962109999999996'),
#   'longitude': Decimal('-93.29142')},
#  {'business_name': 'CHOWGIRLS KILLER CATERING',
#   'address': '336 HOOVER ST NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 88,
#   'neighborhood': 'Mid - City Industrial',
#   'latitude': Decimal('44.9927'),
#   'longitude': Decimal('-93.2183')},
#  {'business_name': 'CHOWGIRLS KILLER CATERING',
#   'address': '336 HOOVER ST NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Mid - City Industrial',
#   'latitude': Decimal('44.9927'),
#   'longitude': Decimal('-93.2183')},
#  {'business_name': 'CHOWGIRLS KILLER CATERING',
#   'address': '336 HOOVER ST NE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Mid - City Industrial',
#   'latitude': Decimal('44.9927'),
#   'longitude': Decimal('-93.2183')},
#  {'business_name': 'POPOL VUH',
#   'address': '1414 QUINCY ST NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 84,
#   'neighborhood': 'Logan Park',
#   'latitude': Decimal('45.002759999999995'),
#   'longitude': Decimal('-93.25158')},
#  {'business_name': 'POPOL VUH',
#   'address': '1414 QUINCY ST NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 90,
#   'neighborhood': 'Logan Park',
#   'latitude': Decimal('45.002759999999995'),
#   'longitude': Decimal('-93.25158')},
#  {'business_name': 'TASTY POT',
#   'address': '423 14TH AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 86,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.981190000000005'),
#   'longitude': Decimal('-93.2356')},
#  {'business_name': 'TASTY POT',
#   'address': '423 14TH AVE SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 94,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.981190000000005'),
#   'longitude': Decimal('-93.2356')},
#  {'business_name': 'TASTY POT',
#   'address': '423 14TH AVE SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 96,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.981190000000005'),
#   'longitude': Decimal('-93.2356')},
#  {'business_name': 'TASTY POT',
#   'address': '423 14TH AVE SE',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.981190000000005'),
#   'longitude': Decimal('-93.2356')},
#  {'business_name': 'TASTY POT',
#   'address': '423 14TH AVE SE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Marcy Holmes',
#   'latitude': Decimal('44.981190000000005'),
#   'longitude': Decimal('-93.2356')},
#  {'business_name': 'UPSTAIRS CIRCUS',
#   'address': '125 WASHINGTON AVE N',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.983270000000005'),
#   'longitude': Decimal('-93.27144')},
#  {'business_name': 'PUERTO VERACRUZANO',
#   'address': '331 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 80,
#   'neighborhood': 'Central',
#   'latitude': Decimal('44.94812'),
#   'longitude': Decimal('-93.2712')},
#  {'business_name': 'PUERTO VERACRUZANO',
#   'address': '331 LAKE ST E',
#   'inspection_type': 'Routine',
#   'inspection_score': 86,
#   'neighborhood': 'Central',
#   'latitude': Decimal('44.94812'),
#   'longitude': Decimal('-93.2712')},
#  {'business_name': 'PUERTO VERACRUZANO',
#   'address': '331 LAKE ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 76,
#   'neighborhood': 'Central',
#   'latitude': Decimal('44.94812'),
#   'longitude': Decimal('-93.2712')},
#  {'business_name': 'PUERTO VERACRUZANO',
#   'address': '331 LAKE ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Central',
#   'latitude': Decimal('44.94812'),
#   'longitude': Decimal('-93.2712')},
#  {'business_name': 'PUERTO VERACRUZANO',
#   'address': '331 LAKE ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 90,
#   'neighborhood': 'Central',
#   'latitude': Decimal('44.94812'),
#   'longitude': Decimal('-93.2712')},
#  {'business_name': 'PUERTO VERACRUZANO',
#   'address': '331 LAKE ST E',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 94,
#   'neighborhood': 'Central',
#   'latitude': Decimal('44.94812'),
#   'longitude': Decimal('-93.2712')},
#  {'business_name': 'LIEN SON RESTAURANT',
#   'address': '1216 BROADWAY ST NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Beltrami',
#   'latitude': Decimal('44.99857'),
#   'longitude': Decimal('-93.24136')},
#  {'business_name': 'LIEN SON RESTAURANT',
#   'address': '1216 BROADWAY ST NE',
#   'inspection_type': 'Routine',
#   'inspection_score': 78,
#   'neighborhood': 'Beltrami',
#   'latitude': Decimal('44.99857'),
#   'longitude': Decimal('-93.24136')},
#  {'business_name': 'LIEN SON RESTAURANT',
#   'address': '1216 BROADWAY ST NE',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Beltrami',
#   'latitude': Decimal('44.99857'),
#   'longitude': Decimal('-93.24136')},
#  {'business_name': 'EUREST @ SRI COFFEE BAR',
#   'address': '111 WASHINGTON AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 98,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.98049'),
#   'longitude': Decimal('-93.26682')},
#  {'business_name': 'HOMEGROWN FOODS',
#   'address': '3717 50TH ST W',
#   'inspection_type': 'Routine',
#   'inspection_score': 90,
#   'neighborhood': 'Fulton',
#   'latitude': Decimal('44.91218'),
#   'longitude': Decimal('-93.3274')},
#  {'business_name': 'HOMEGROWN FOODS',
#   'address': '3717 50TH ST W',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 98,
#   'neighborhood': 'Fulton',
#   'latitude': Decimal('44.91218'),
#   'longitude': Decimal('-93.3274')},
#  {'business_name': 'PARALLEL',
#   'address': '145 HOLDEN ST N',
#   'inspection_type': 'Routine',
#   'inspection_score': 94,
#   'neighborhood': 'North Loop',
#   'latitude': Decimal('44.97948'),
#   'longitude': Decimal('-93.28425')},
#  {'business_name': 'PARALLEL',
#   'address': '145 HOLDEN ST N',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'North Loop',
#   'latitude': Decimal('44.97948'),
#   'longitude': Decimal('-93.28425')},
#  {'business_name': 'DANCING GANESHA',
#   'address': '1100 HARMON PL',
#   'inspection_type': 'Routine',
#   'inspection_score': 86,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97428'),
#   'longitude': Decimal('-93.27887')},
#  {'business_name': 'DANCING GANESHA',
#   'address': '1100 HARMON PL',
#   'inspection_type': 'Routine',
#   'inspection_score': 86,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97428'),
#   'longitude': Decimal('-93.27887')},
#  {'business_name': 'DANCING GANESHA',
#   'address': '1100 HARMON PL',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97428'),
#   'longitude': Decimal('-93.27887')},
#  {'business_name': 'DANCING GANESHA',
#   'address': '1100 HARMON PL',
#   'inspection_type': 'Follow-Up',
#   'inspection_score': 92,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97428'),
#   'longitude': Decimal('-93.27887')},
#  {'business_name': 'NAF NAF GRILL',
#   'address': '121 8TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97441'),
#   'longitude': Decimal('-93.27109')},
#  {'business_name': 'NAF NAF GRILL',
#   'address': '121 8TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.97441'),
#   'longitude': Decimal('-93.27109')},
#  {'business_name': 'TOPPERS PIZZA',
#   'address': '2936 LYNDALE AVE S',
#   'inspection_type': 'Routine',
#   'inspection_score': 100,
#   'neighborhood': 'Lowry Hill East',
#   'latitude': Decimal('44.94878'),
#   'longitude': Decimal('-93.28851999999999')},
#  {'business_name': 'LUMINN HOTEL MINNEAPOLIS',
#   'address': '219 4TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.977990000000005'),
#   'longitude': Decimal('-93.26645')},
#  {'business_name': 'LUMINN HOTEL MINNEAPOLIS',
#   'address': '219 4TH ST S',
#   'inspection_type': 'Routine',
#   'inspection_score': 96,
#   'neighborhood': 'Downtown West',
#   'latitude': Decimal('44.977990000000005'),
#   'longitude': Decimal('-93.26645')},
#  {'business_name': 'RED COW',
#   'address': '2626 HENNEPIN AVE',
#   'inspection_type': 'Routine',
#   'inspection_score': 92,
#   'neighborhood': 'East Isles',
#   'latitude': Decimal('44.95469'),
#   'longitude': Decimal('-93.29767')},
#  ...]
